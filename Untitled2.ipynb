# %%
from turtle import *
from random import *
wn = Screen()
wn.bgcolor("tan")
wn.title("Turtle")

t1=Turtle()
t2=Turtle()
t3=Turtle()
t4=Turtle()
t=Turtle()

def fun():
    t.hideturtle()
    t.speed(9)
    for i in range(4):
        #first line
        t.showturtle()
        t.forward(200)
        t.left(90)
        t.forward(100)
        t.right(90)
        t.forward(200)
        t.left(90)
        t.forward(100)
        t.right(90)
        t.forward(200)
        t.right(90)
        t.forward(100)
        t.left(90)
        t.forward(200)
        t.right(90)
        t.forward(100)
        t.left(90)
        t.forward(200)
        
         #back to initial
        t.right(90)
        t.penup()
        t.forward(150)
        t.right(90)
        t.forward(1000)
        t.right(90)
        t.forward(50)
        t.forward(50)
        t.right(90)
        t.pendown()
       
        #second line
        t.forward(300)
        t.left(90)
        t.forward(100)
        t.right(90)
        t.forward(150)

        t.left(90)
        t.forward(100)
        t.right(90)
        t.forward(100)
        t.right(90)
        t.forward(100)
        t.left(90)
        t.forward(150)
        t.right(90)
        t.forward(100)
        t.left(90)
        t.forward(300)
        
        #back to initial
        t.right(90)
        t.penup()
        t.forward(200)
        t.right(90)
        t.forward(1000)
        t.right(90)
        t.forward(50)
        t.right(90)
        t.pendown()
        t.hideturtle()
    t.hideturtle()

def tur1():
    t1.hideturtle()
    t1.shape("turtle")
    t1.color("blue")
    t1.penup()
    t1.goto(-400,+275)
    t1.pendown()
    t1.showturtle()

def tur2():    
    t2.hideturtle()
    t2.shape("turtle")
    t2.color("red")
    t2.penup()
    t2.goto(-400,+75)
    t2.pendown()
    t2.showturtle()

def tur3():
    t3.hideturtle()
    t3.shape("turtle")
    t3.color("purple")
    t3.penup()
    t3.goto(-400,-125)
    t3.pendown()
    t3.showturtle()

def tur4():
    t4.hideturtle()
    t4.shape("turtle")
    t4.color("green")
    t4.penup()
    t4.goto(-400,-325)
    t4.pendown()
    t4.showturtle()

def maze():    
    t.hideturtle()
    t.shape("circle")
    t.color('black')
    t.penup()
    t.goto(-400,+300)
    t.pendown()
    t.showturtle()
    
def workTur1():
    
    t1.speed(randint(1,5)-2)
    t2.speed(randint(1,5)-1)
    t3.speed(randint(1,5))
    t4.speed(randint(1,5)+1)
    
    t1.forward(250)    
    t2.forward(250)
    t3.forward(250)
    t4.forward(250)
    
    t1.left(90)
    t2.left(90)
    t3.left(90)
    t4.left(90)
        
    t1.forward(100)
    t2.forward(100)
    t3.forward(100)
    t4.forward(100)
    
    t1.right(90)
    t2.right(90)
    t3.right(90)
    t4.right(90)
    
    t1.forward(175)
    t2.forward(175)
    t3.forward(175)
    t4.forward(175)
    
    t1.left(90)
    t2.left(90)
    t3.left(90)
    t4.left(90)
    
    t1.forward(100)
    t2.forward(100)
    t3.forward(100)
    t4.forward(100)
    
    t1.right(90)
    t2.right(90)
    t3.right(90)
    t4.right(90)
    
    t1.forward(150)
    t2.forward(150)
    t3.forward(150)
    t4.forward(150)
    
    t1.right(90)
    t2.right(90)
    t3.right(90)
    t4.right(90)
    
    t1.forward(100)
    t2.forward(100)
    t3.forward(100)
    t4.forward(100)
    
    t1.left(90)
    t2.left(90)
    t3.left(90)
    t4.left(90)
    
    t1.forward(175)
    t2.forward(175)
    t3.forward(175)
    t4.forward(175)
    
    t1.right(90)
    t2.right(90)
    t3.right(90)
    t4.right(90)
    
    t1.forward(100)
    t2.forward(100)
    t3.forward(100)
    t4.forward(100)
    
    t1.left(90)
    t2.left(90)
    t3.left(90)
    t4.left(90)
    
    for i in range(100):
        t1.forward(randint(1,5))
        t2.forward(randint(1,5))
        t3.forward(randint(1,5))
        t4.forward(randint(1,5))


maze()
fun()
tur1()
tur2()
tur3()
tur4()
workTur1()
